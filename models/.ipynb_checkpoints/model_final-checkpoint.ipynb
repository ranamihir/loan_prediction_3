# %%
# Initial imports

import numpy as np
import pandas as pd 
from pandas import DataFrame, Series
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %matplotlib inline

# %%
# Imports for better visualization

from collections import defaultdict
import json

import scipy as sp

from matplotlib import rcParams
import matplotlib.cm as cm
import matplotlib as mpl

#colorbrewer2 Dark2 qualitative color table
dark2_colors = [(0.10588235294117647, 0.6196078431372549, 0.4666666666666667),
                (0.8509803921568627, 0.37254901960784315, 0.00784313725490196),
                (0.4588235294117647, 0.4392156862745098, 0.7019607843137254),
                (0.9058823529411765, 0.1607843137254902, 0.5411764705882353),
                (0.4, 0.6509803921568628, 0.11764705882352941),
                (0.9019607843137255, 0.6705882352941176, 0.00784313725490196),
                (0.6509803921568628, 0.4627450980392157, 0.11372549019607843)]

rcParams['figure.figsize'] = (10, 6)
rcParams['figure.dpi'] = 150
rcParams['axes.color_cycle'] = dark2_colors
rcParams['lines.linewidth'] = 2
rcParams['axes.facecolor'] = 'white'
rcParams['font.size'] = 14
rcParams['patch.edgecolor'] = 'white'
rcParams['patch.facecolor'] = dark2_colors[0]
rcParams['font.family'] = 'StixGeneral'
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/__init__.py:913: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
# Load training data
train_data = pd.read_csv('../data/train.csv')

# %%
# Load testing data
test_data = pd.read_csv('../data/test.csv')

# %%
# View train data head
train_data.head(10)
# Out:
#      ID  timestamp  Stock_ID   Volume  Three_Day_Moving_Average  \
# 0   1_1          1         1 -0.33308                  -0.99681
# 1   3_1          1         3 -0.67096                  -2.08895
# 2   4_1          1         4 -0.22040                   1.07839
# 3   6_1          1         6 -0.23118                  -0.55106
# 4  10_1          1        10  0.15076                  -1.40937
# 5  11_1          1        11 -0.57249                   0.61078
# 6  12_1          1        12  0.91950                   0.69282
# 7  13_1          1        13  0.36579                  -0.61906
# 8  14_1          1        14 -0.37675                  -1.07755
# 9  15_1          1        15  0.19038                   3.73614
#
#    Five_Day_Moving_Average  Ten_Day_Moving_Average  Twenty_Day_Moving_Average  \
# 0                 -0.98736                -0.94728                   -0.91977
# 1                 -2.08251                -2.02183                   -1.93779
# 2                  1.09143                 1.18737                        NaN
# 3                 -0.53976                -0.47569                   -0.42449
# 4                 -1.39805                -1.36756                   -1.31365
# 5                  0.62465                 0.64510                    0.76290
# 6                  0.69202                 0.72082                    0.70390
# 7                 -0.59099                -0.50427                   -0.45347
# 8                 -1.06405                -1.02723                   -0.99213
# 9                  3.76318                 3.81298                    3.82002
#
#    True_Range  Average_True_Range  Positive_Directional_Movement  \
# 0    -0.21129            -0.38778                       -0.39903
# 1    -0.46476             0.97308                       -0.31078
# 2    -0.51638            -0.52368                       -0.24140
# 3    -0.60816            -0.69311                       -0.40673
# 4    -0.33206            -0.43690                       -0.33347
# 5     1.21998             1.02812                        1.44735
# 6     0.05071            -0.79388                       -0.43920
# 7    -0.17573            -0.18656                       -0.42729
# 8    -0.45472            -0.78394                       -0.39440
# 9     1.34630             1.54563                       -0.36749
#
#    Negative_Directional_Movement  Outcome
# 0                       -0.14321        1
# 1                        0.80286        0
# 2                       -0.31910        0
# 3                       -0.45965        0
# 4                        0.29217        0
# 5                       -0.40430        1
# 6                       -0.47780        0
# 7                       -0.05086        0
# 8                       -0.39275        0
# 9                        0.18381        0

# %%
# View test data head
test_data.head(10)
# Out:
#        ID  timestamp  Stock_ID   Volume  Three_Day_Moving_Average  \
# 0   1_554        554         1  0.43959                  -1.09885
# 1   2_554        554         2 -0.38494                  -0.64131
# 2   3_554        554         3  1.38417                  -0.53956
# 3   4_554        554         4 -0.22040                  -1.64317
# 4   6_554        554         6 -0.21500                   0.14539
# 5   7_554        554         7  0.30540                   0.50061
# 6   9_554        554         9 -0.24666                  -1.42346
# 7  10_554        554        10  2.67942                  -0.32910
# 8  11_554        554        11 -0.10141                  -0.99765
# 9  12_554        554        12  0.11787                  -2.15749
#
#    Five_Day_Moving_Average  Ten_Day_Moving_Average  Twenty_Day_Moving_Average  \
# 0                 -1.08146                -1.02367                   -0.95527
# 1                 -0.64340                -0.63477                   -0.61062
# 2                 -0.46261                -0.22662                   -0.15185
# 3                 -1.66702                -1.66951                   -1.58663
# 4                  0.12088                 0.15728                    0.13933
# 5                  0.42719                 0.55069                    0.38243
# 6                 -1.41889                -1.39010                   -1.40196
# 7                 -0.30959                -0.19959                   -0.06020
# 8                 -0.98638                -0.96689                   -0.96781
# 9                 -2.16635                -2.16211                   -2.14986
#
#    True_Range  Average_True_Range  Positive_Directional_Movement  \
# 0     0.11595             0.17058                       -0.39903
# 1    -0.47816            -0.48696                       -0.28545
# 2     0.27538             0.86787                       -0.31078
# 3    -0.51638             0.04259                       -0.24140
# 4     0.10491            -0.63238                       -0.40673
# 5     3.18863             1.57867                       -0.35039
# 6    -0.22637             0.06181                       -0.33927
# 7     1.67859             3.06438                       -0.33347
# 8    -0.81608            -0.14644                       -0.39786
# 9    -0.42887            -0.18222                       -0.43920
#
#    Negative_Directional_Movement
# 0                       -0.33365
# 1                       -0.30166
# 2                       -0.43770
# 3                       -0.31910
# 4                       -0.45965
# 5                       -0.50291
# 6                       -0.46579
# 7                       -0.48861
# 8                       -0.40430
# 9                       -0.47780

# %%
train_data.dtypes
# Out:
# ID                                object
# timestamp                          int64
# Stock_ID                           int64
# Volume                           float64
# Three_Day_Moving_Average         float64
# Five_Day_Moving_Average          float64
# Ten_Day_Moving_Average           float64
# Twenty_Day_Moving_Average        float64
# True_Range                       float64
# Average_True_Range               float64
# Positive_Directional_Movement    float64
# Negative_Directional_Movement    float64
# Outcome                            int64
# dtype: object

# %%
test_data.dtypes
# Out:
# ID                                object
# timestamp                          int64
# Stock_ID                           int64
# Volume                           float64
# Three_Day_Moving_Average         float64
# Five_Day_Moving_Average          float64
# Ten_Day_Moving_Average           float64
# Twenty_Day_Moving_Average        float64
# True_Range                       float64
# Average_True_Range               float64
# Positive_Directional_Movement    float64
# Negative_Directional_Movement    float64
# dtype: object

# %%
# View train data shape
train_data.shape
# Out:
# (702739, 13)

# %%
# Check for null values in train data
train_data.isnull().any()
# Out:
# ID                               False
# timestamp                        False
# Stock_ID                         False
# Volume                           False
# Three_Day_Moving_Average          True
# Five_Day_Moving_Average           True
# Ten_Day_Moving_Average            True
# Twenty_Day_Moving_Average         True
# True_Range                       False
# Average_True_Range                True
# Positive_Directional_Movement     True
# Negative_Directional_Movement     True
# Outcome                          False
# dtype: bool

# %%
# View test data shape
test_data.shape
# Out:
# (101946, 12)

# %%
# Check for null values in test data
test_data.isnull().any()
# Out:
# ID                               False
# timestamp                        False
# Stock_ID                         False
# Volume                           False
# Three_Day_Moving_Average          True
# Five_Day_Moving_Average           True
# Ten_Day_Moving_Average            True
# Twenty_Day_Moving_Average         True
# True_Range                       False
# Average_True_Range                True
# Positive_Directional_Movement     True
# Negative_Directional_Movement     True
# dtype: bool

# %%
def num_missing(x):
  return sum(x.isnull())

# %%
print "Missing values per column:"
print train_data.apply(num_missing, axis=0) # axis=0 defines that function is to be applied on each column
# Out:
# Missing values per column:
# ID                                  0
# timestamp                           0
# Stock_ID                            0
# Volume                              0
# Three_Day_Moving_Average          448
# Five_Day_Moving_Average           902
# Ten_Day_Moving_Average           2047
# Twenty_Day_Moving_Average        4404
# True_Range                          0
# Average_True_Range               2985
# Positive_Directional_Movement     224
# Negative_Directional_Movement     224
# Outcome                             0
# dtype: int64

# %%
print "Missing values per column:"
print test_data.apply(num_missing, axis=0)
# Out:
# Missing values per column:
# ID                                 0
# timestamp                          0
# Stock_ID                           0
# Volume                             0
# Three_Day_Moving_Average          54
# Five_Day_Moving_Average          127
# Ten_Day_Moving_Average           280
# Twenty_Day_Moving_Average        587
# True_Range                         0
# Average_True_Range               401
# Positive_Directional_Movement    100
# Negative_Directional_Movement     61
# dtype: int64

# %%
def fill_na(df):
    for col in train_data.columns[train_data.isnull().any()]:
        df[col] = df.groupby('Stock_ID').transform(lambda x: x.fillna(x.mean()))[col]
    return df

# %%
train_data = fill_na(train_data)
test_data = fill_na(test_data)

# %%
print train_data.apply(num_missing, axis=0)
# Out:
# ID                                0
# timestamp                         0
# Stock_ID                          0
# Volume                            0
# Three_Day_Moving_Average          2
# Five_Day_Moving_Average           2
# Ten_Day_Moving_Average            2
# Twenty_Day_Moving_Average        30
# True_Range                        0
# Average_True_Range               14
# Positive_Directional_Movement     2
# Negative_Directional_Movement     2
# Outcome                           0
# dtype: int64

# %%
print test_data.apply(num_missing, axis=0)
# Out:
# ID                                0
# timestamp                         0
# Stock_ID                          0
# Volume                            0
# Three_Day_Moving_Average          3
# Five_Day_Moving_Average           3
# Ten_Day_Moving_Average            3
# Twenty_Day_Moving_Average         9
# True_Range                        0
# Average_True_Range                0
# Positive_Directional_Movement    76
# Negative_Directional_Movement    37
# dtype: int64

# %%
for col in train_data.columns[train_data.isnull().any()]:
    if train_data[col].isnull().any():
        train_data[col].fillna(np.mean(train_data[col].dropna()), inplace=True)

# %%
for col in test_data.columns[test_data.isnull().any()]:
    if test_data[col].isnull().any():
        test_data[col].fillna(np.mean(test_data[col].dropna()), inplace=True)

# %%
print train_data.apply(num_missing, axis=0)
# Out:
# ID                               0
# timestamp                        0
# Stock_ID                         0
# Volume                           0
# Three_Day_Moving_Average         0
# Five_Day_Moving_Average          0
# Ten_Day_Moving_Average           0
# Twenty_Day_Moving_Average        0
# True_Range                       0
# Average_True_Range               0
# Positive_Directional_Movement    0
# Negative_Directional_Movement    0
# Outcome                          0
# dtype: int64

# %%
print test_data.apply(num_missing, axis=0)
# Out:
# ID                               0
# timestamp                        0
# Stock_ID                         0
# Volume                           0
# Three_Day_Moving_Average         0
# Five_Day_Moving_Average          0
# Ten_Day_Moving_Average           0
# Twenty_Day_Moving_Average        0
# True_Range                       0
# Average_True_Range               0
# Positive_Directional_Movement    0
# Negative_Directional_Movement    0
# dtype: int64

# %%
train_data['Stock_ID'].value_counts()
# Out:
# 201     394
# 1535    380
# 159     380
# 1690    380
# 155     380
# 1179    380
# 668     380
# 1180    380
# 1692    380
# 669     380
# 1181    380
# 1693    380
# 158     380
# 1182    380
# 671     380
# 1689    380
# 672     380
# 1184    380
# 1696    380
# 673     380
# 1185    380
# 1697    380
# 162     380
# 674     380
# 163     380
# 1187    380
# 676     380
# 666     380
# 1177    380
# 1700    380
#        ...
# 1842     67
# 1950     67
# 1342     63
# 1910     63
# 154      63
# 1841     60
# 1833     59
# 46       59
# 1220     58
# 1770     58
# 834      57
# 2199     57
# 1436     52
# 112      52
# 1778     51
# 706      51
# 1446     41
# 589      40
# 807      39
# 2111     36
# 93       35
# 2169     32
# 593      32
# 202      27
# 1404     26
# 291      26
# 1753     16
# 1781     12
# 1442      1
# 1579      1
# Name: Stock_ID, dtype: int64

# %%
# Import for Oversampling
from imblearn.over_sampling import RandomOverSampler

# %%
train_features = train_data.copy().drop(['ID', 'Stock_ID'], axis=1)
target = train_data.copy()['Stock_ID']

# %%
# 'Random over-sampling'
OS = RandomOverSampler(ratio='auto')
train_os_features, train_os_target = OS.fit_sample(train_features, target.values.ravel())


# Convert the generated numpy arrays into data frames
train_os_features = DataFrame(train_os_features, columns=train_features.columns)
train_os_target = DataFrame(train_os_target, columns=['Stock_ID'])

# %%
print train_os_target.shape
print train_os_target['Stock_ID'].value_counts()
# Out:
# (770270, 1)
# 1535    394
# 655     394
# 1679    394
# 144     394
# 2193    394
# 656     394
# 1168    394
# 2192    394
# 145     394
# 657     394
# 1169    394
# 1681    394
# 146     394
# 2195    394
# 658     394
# 1170    394
# 1682    394
# 2194    394
# 147     394
# 659     394
# 1171    394
# 148     394
# 2197    394
# 660     394
# 1684    394
# 2196    394
# 149     394
# 661     394
# 1173    394
# 1167    394
#        ...
# 842     394
# 1865    394
# 1861    394
# 1858    394
# 323     394
# 835     394
# 1347    394
# 1859    394
# 324     394
# 836     394
# 1348    394
# 1860    394
# 325     394
# 837     394
# 1349    394
# 326     394
# 1353    394
# 838     394
# 1350    394
# 1862    394
# 327     394
# 839     394
# 1351    394
# 328     394
# 840     394
# 1352    394
# 1864    394
# 329     394
# 841     394
# 2049    394
# Name: Stock_ID, dtype: int64

# %%
train_os_features.columns
# Out:
# Index([u'timestamp', u'Volume', u'Three_Day_Moving_Average',
#        u'Five_Day_Moving_Average', u'Ten_Day_Moving_Average',
#        u'Twenty_Day_Moving_Average', u'True_Range', u'Average_True_Range',
#        u'Positive_Directional_Movement', u'Negative_Directional_Movement',
#        u'Outcome'],
#       dtype='object')

# %%
train = train_os_features
train['Stock_ID'] = train_os_target

# %%
test = test_data.copy().drop(['ID'], axis=1)

# %%
train.head()
# Out:
#    timestamp   Volume  Three_Day_Moving_Average  Five_Day_Moving_Average  \
# 0        1.0 -0.28294                   1.29050                  1.29969
# 1        2.0 -0.22219                   1.29899                  1.29308
# 2        3.0 -0.26969                   1.28303                  1.29554
# 3        4.0 -0.28515                   1.31525                  1.29474
# 4        5.0 -0.33707                   1.24322                  1.25112
#
#    Ten_Day_Moving_Average  Twenty_Day_Moving_Average  True_Range  \
# 0                 1.28249                    1.30620     0.12260
# 1                 1.28696                    1.29460    -0.11239
# 2                 1.29302                    1.29177     0.16960
# 3                 1.28865                    1.28410     0.43278
# 4                 1.27274                    1.27269     0.63957
#
#    Average_True_Range  Positive_Directional_Movement  \
# 0             0.74343                       -0.36854
# 1             0.49819                       -0.36854
# 2             0.34582                        0.93883
# 3             0.30597                       -0.36854
# 4             0.37504                       -0.36854
#
#    Negative_Directional_Movement  Outcome  Stock_ID
# 0                       -0.33701      0.0       201
# 1                        0.06859      1.0       201
# 2                       -0.33701      0.0       201
# 3                       -0.33701      0.0       201
# 4                       -0.33701      1.0       201

# %%
# Imports for model
from sklearn.metrics import log_loss
from xgboost.sklearn import XGBRegressor
# Out:
# /usr/local/lib/python2.7/dist-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
# XGBoost Model

# Since this data is time-based, divide train data into two sets, one for training (till timestamp < 550), and other for testing (timestamp == 550)
# Then drop timestamp column (it is pure noise, since no year in train data matched that in test data)
# Fit XGBRegressor

xgbr = XGBRegressor(n_estimators=100, max_depth=8, silent=False)
x_train = train[train['timestamp'] < 549].drop(['Outcome'], axis=1)
y_train = train[train['timestamp'] < 549]['Outcome']
x_test = train[train['timestamp'] >= 549].drop(['Outcome'], axis=1)
y_test = train[train['timestamp'] >= 549]['Outcome']
x_train.drop(['timestamp'], axis=1, inplace=True)
x_test.drop(['timestamp'], axis=1, inplace=True)
xgbr.fit(x_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, colsample_bylevel=1, colsample_bytree=1, gamma=0,
#        learning_rate=0.1, max_delta_step=0, max_depth=8,
#        min_child_weight=1, missing=None, n_estimators=100, nthread=-1,
#        objective='reg:linear', reg_alpha=0, reg_lambda=1,
#        scale_pos_weight=1, seed=0, silent=False, subsample=1)

# %%
# Predict values on test data
predicted_train = xgbr.predict(x_test)

# %%
# Print log-loss
print log_loss(y_test, predicted_train)
# Out:
# 0.667832626633

# %%
# Use complete data and predict values on actual test data
xgbr.fit(train.drop(['timestamp', 'Outcome'], axis=1), train['Outcome'])
predicted_xgbr = xgbr.predict(test[x_test.columns])

# %%
# Create solution dataframe
solution_xgbr = pd.DataFrame(test_data['ID'])
solution_xgbr = pd.concat([solution_xgbr, pd.DataFrame(predicted_xgbr, columns=['Outcome'])], axis=1)
solution_xgbr
# Out:
#               ID   Outcome
# 0          1_554  0.457646
# 1          2_554  0.386978
# 2          3_554  0.466758
# 3          4_554  0.211573
# 4          6_554  0.439988
# 5          7_554  0.453570
# 6          9_554  0.409505
# 7         10_554  0.512541
# 8         11_554  0.440608
# 9         12_554  0.614689
# 10        13_554  0.605941
# 11        14_554  0.490420
# 12        15_554  0.434171
# 13        16_554  0.489486
# 14        17_554  0.583225
# 15        18_554  0.475283
# 16        19_554  0.397227
# 17        20_554  0.537878
# 18        21_554  0.392809
# 19        22_554  0.469317
# 20        23_554  0.507983
# 21        24_554  0.496147
# 22        25_554  0.558224
# 23        26_554  0.474068
# 24        27_554  0.535323
# 25        28_554  0.596795
# 26        29_554  0.493011
# 27        30_554  0.597960
# 28        31_554  0.352490
# 29        32_554  0.565474
# ...          ...       ...
# 101916  2169_953  0.472594
# 101917  2170_953  0.467327
# 101918  2171_953  0.436462
# 101919  2172_953  0.445127
# 101920  2173_953  0.395820
# 101921  2174_953  0.451854
# 101922  2175_953  0.461155
# 101923  2176_953  0.243082
# 101924  2177_953  0.438413
# 101925  2178_953  0.484695
# 101926  2179_953  0.418269
# 101927  2180_953  0.356554
# 101928  2181_953  0.536833
# 101929  2182_953  0.428026
# 101930  2183_953  0.491714
# 101931  2185_953  0.561900
# 101932  2186_953  0.391777
# 101933  2187_953  0.384424
# 101934  2188_953  0.432806
# 101935  2189_953  0.432438
# 101936  2190_953  0.224029
# 101937  2191_953  0.586490
# 101938  2192_953  0.472332
# 101939  2193_953  0.540548
# 101940  2194_953  0.415394
# 101941  2195_953  0.369290
# 101942  2196_953  0.404726
# 101943  2197_953  0.433174
# 101944  2198_953  0.369586
# 101945  2199_953  0.420970
#
# [101946 rows x 2 columns]

# %%
# Export solution to csv file
solution_xgbr.to_csv('../submissions/solution_xgbr.csv', index=False)

# %%
import xgboost as xgb
params = {"objective": "binary:logistic",
          "booster" : "gbtree",
          "eta": 0.05,
          "max_depth": 8,
          "subsample": 0.75,
          "colsample_bytree": 0.5,
          'gamma':1.0,
          'min_child_weight':5,
          "silent": 1,
          "seed": 1301,
          "eval_metric": 'logloss'
          }
num_boost_round = 200

# %%
print("Train a XGBoost model")
dtrain = xgb.DMatrix(x_train, y_train)
dvalid = xgb.DMatrix(x_test, y_test)

watchlist = [(dtrain, 'train'), (dvalid, 'eval')]
gbm = xgb.train(params, dtrain, num_boost_round, evals=watchlist, early_stopping_rounds=50, verbose_eval=True)
# Out:
# Train a XGBoost model
# [0]	train-logloss:0.691776	eval-logloss:0.69171
# Multiple eval metrics have been passed: 'eval-logloss' will be used for early stopping.
#
# Will train until eval-logloss hasn't improved in 50 rounds.
# [1]	train-logloss:0.69051	eval-logloss:0.688849
# [2]	train-logloss:0.689551	eval-logloss:0.687767
# [3]	train-logloss:0.688643	eval-logloss:0.686589
# [4]	train-logloss:0.687744	eval-logloss:0.68557
# [5]	train-logloss:0.686808	eval-logloss:0.684415
# [6]	train-logloss:0.685961	eval-logloss:0.683644
# [7]	train-logloss:0.685202	eval-logloss:0.684121
# [8]	train-logloss:0.68452	eval-logloss:0.682736
# [9]	train-logloss:0.68404	eval-logloss:0.681791
# [10]	train-logloss:0.68348	eval-logloss:0.680854
# [11]	train-logloss:0.682914	eval-logloss:0.680067
# [12]	train-logloss:0.682564	eval-logloss:0.679785
# [13]	train-logloss:0.682156	eval-logloss:0.679078
# [14]	train-logloss:0.681645	eval-logloss:0.67857
# [15]	train-logloss:0.681337	eval-logloss:0.678116
# [16]	train-logloss:0.680801	eval-logloss:0.677643
# [17]	train-logloss:0.680405	eval-logloss:0.677352
# [18]	train-logloss:0.679964	eval-logloss:0.676812
# [19]	train-logloss:0.67951	eval-logloss:0.676312
# [20]	train-logloss:0.679117	eval-logloss:0.67596
# [21]	train-logloss:0.678807	eval-logloss:0.675375
# [22]	train-logloss:0.678577	eval-logloss:0.675047
# [23]	train-logloss:0.678335	eval-logloss:0.674679
# [24]	train-logloss:0.677966	eval-logloss:0.674283
# [25]	train-logloss:0.677687	eval-logloss:0.674117
# [26]	train-logloss:0.677427	eval-logloss:0.673974
# [27]	train-logloss:0.677185	eval-logloss:0.673838
# [28]	train-logloss:0.676951	eval-logloss:0.673281
# [29]	train-logloss:0.676723	eval-logloss:0.672934
# [30]	train-logloss:0.676547	eval-logloss:0.672647
# [31]	train-logloss:0.676309	eval-logloss:0.672821
# [32]	train-logloss:0.676159	eval-logloss:0.672619
# [33]	train-logloss:0.675997	eval-logloss:0.672359
# [34]	train-logloss:0.675794	eval-logloss:0.67218
# [35]	train-logloss:0.67569	eval-logloss:0.671993
# [36]	train-logloss:0.675524	eval-logloss:0.671991
# [37]	train-logloss:0.675336	eval-logloss:0.671718
# [38]	train-logloss:0.67516	eval-logloss:0.67145
# [39]	train-logloss:0.674998	eval-logloss:0.671146
# [40]	train-logloss:0.674887	eval-logloss:0.670967
# [41]	train-logloss:0.674719	eval-logloss:0.67104
# [42]	train-logloss:0.674558	eval-logloss:0.670966
# [43]	train-logloss:0.674406	eval-logloss:0.670653
# [44]	train-logloss:0.67425	eval-logloss:0.670613
# [45]	train-logloss:0.67417	eval-logloss:0.670581
# [46]	train-logloss:0.674033	eval-logloss:0.670689
# [47]	train-logloss:0.67392	eval-logloss:0.670436
# [48]	train-logloss:0.673774	eval-logloss:0.67034
# [49]	train-logloss:0.673644	eval-logloss:0.67034
# [50]	train-logloss:0.673538	eval-logloss:0.67016
# [51]	train-logloss:0.673431	eval-logloss:0.669854
# [52]	train-logloss:0.67329	eval-logloss:0.669757
# [53]	train-logloss:0.673107	eval-logloss:0.669563
# [54]	train-logloss:0.672959	eval-logloss:0.669577
# [55]	train-logloss:0.672852	eval-logloss:0.669574
# [56]	train-logloss:0.672672	eval-logloss:0.669524
# [57]	train-logloss:0.672575	eval-logloss:0.669449
# [58]	train-logloss:0.672479	eval-logloss:0.669467
# [59]	train-logloss:0.672411	eval-logloss:0.669326
# [60]	train-logloss:0.67228	eval-logloss:0.669179
# [61]	train-logloss:0.672196	eval-logloss:0.669125
# [62]	train-logloss:0.672137	eval-logloss:0.669258
# [63]	train-logloss:0.67204	eval-logloss:0.669609
# [64]	train-logloss:0.671938	eval-logloss:0.669589
# [65]	train-logloss:0.671854	eval-logloss:0.669551
# [66]	train-logloss:0.671792	eval-logloss:0.669545
# [67]	train-logloss:0.671665	eval-logloss:0.669618
# [68]	train-logloss:0.671582	eval-logloss:0.669535
# [69]	train-logloss:0.671499	eval-logloss:0.669419
# [70]	train-logloss:0.671341	eval-logloss:0.669398
# [71]	train-logloss:0.6712	eval-logloss:0.669589
# [72]	train-logloss:0.671124	eval-logloss:0.669633
# [73]	train-logloss:0.671014	eval-logloss:0.669636
# [74]	train-logloss:0.670959	eval-logloss:0.669561
# [75]	train-logloss:0.67086	eval-logloss:0.669585
# [76]	train-logloss:0.67078	eval-logloss:0.669641
# [77]	train-logloss:0.670671	eval-logloss:0.669592
# [78]	train-logloss:0.670605	eval-logloss:0.669554
# [79]	train-logloss:0.670544	eval-logloss:0.6695
# [80]	train-logloss:0.670475	eval-logloss:0.669483
# [81]	train-logloss:0.670416	eval-logloss:0.66952
# [82]	train-logloss:0.670343	eval-logloss:0.669389
# [83]	train-logloss:0.6703	eval-logloss:0.66931
# [84]	train-logloss:0.670202	eval-logloss:0.669346
# [85]	train-logloss:0.670165	eval-logloss:0.669295
# [86]	train-logloss:0.670117	eval-logloss:0.669353
# [87]	train-logloss:0.670041	eval-logloss:0.669327
# [88]	train-logloss:0.669966	eval-logloss:0.669239
# [89]	train-logloss:0.669908	eval-logloss:0.669303
# [90]	train-logloss:0.6698	eval-logloss:0.669424
# [91]	train-logloss:0.669761	eval-logloss:0.669408
# [92]	train-logloss:0.669697	eval-logloss:0.669442
# [93]	train-logloss:0.669653	eval-logloss:0.669267
# [94]	train-logloss:0.669577	eval-logloss:0.669204
# [95]	train-logloss:0.669466	eval-logloss:0.669252
# [96]	train-logloss:0.669417	eval-logloss:0.669304
# [97]	train-logloss:0.669318	eval-logloss:0.669354
# [98]	train-logloss:0.669234	eval-logloss:0.669501
# [99]	train-logloss:0.669188	eval-logloss:0.669538
# [100]	train-logloss:0.669113	eval-logloss:0.669826
# [101]	train-logloss:0.669051	eval-logloss:0.669694
# [102]	train-logloss:0.66901	eval-logloss:0.669694
# [103]	train-logloss:0.668941	eval-logloss:0.671072
# [104]	train-logloss:0.668916	eval-logloss:0.67099
# [105]	train-logloss:0.668905	eval-logloss:0.670959
# [106]	train-logloss:0.668824	eval-logloss:0.670914
# [107]	train-logloss:0.668793	eval-logloss:0.67092
# [108]	train-logloss:0.668751	eval-logloss:0.670861
# [109]	train-logloss:0.668696	eval-logloss:0.67087
# [110]	train-logloss:0.668648	eval-logloss:0.670973
# [111]	train-logloss:0.668567	eval-logloss:0.671047
# Stopping. Best iteration:
# [61]	train-logloss:0.672196	eval-logloss:0.669125

# %%
# Use complete data and predict values on actual test data

print("Train a XGBoost model")
dtrain = xgb.DMatrix(train.drop(['timestamp', 'Outcome'], axis=1), train['Outcome'])

watchlist = [(dtrain, 'train')]
gbm = xgb.train(params, dtrain, num_boost_round, evals=watchlist, early_stopping_rounds=50, verbose_eval=True)
# Out:
# Train a XGBoost model
# [0]	train-logloss:0.692
# Will train until train-logloss hasn't improved in 50 rounds.
# [1]	train-logloss:0.691187
# [2]	train-logloss:0.690055
# [3]	train-logloss:0.68887
# [4]	train-logloss:0.687999
# [5]	train-logloss:0.687253
# [6]	train-logloss:0.686332
# [7]	train-logloss:0.685477
# [8]	train-logloss:0.684914
# [9]	train-logloss:0.684151
# [10]	train-logloss:0.683589
# [11]	train-logloss:0.683155
# [12]	train-logloss:0.682657
# [13]	train-logloss:0.682091
# [14]	train-logloss:0.681556
# [15]	train-logloss:0.681122
# [16]	train-logloss:0.680586
# [17]	train-logloss:0.680098
# [18]	train-logloss:0.679787
# [19]	train-logloss:0.679535
# [20]	train-logloss:0.679141
# [21]	train-logloss:0.678694
# [22]	train-logloss:0.678354
# [23]	train-logloss:0.678031
# [24]	train-logloss:0.677747
# [25]	train-logloss:0.677495
# [26]	train-logloss:0.677229
# [27]	train-logloss:0.677023
# [28]	train-logloss:0.676788
# [29]	train-logloss:0.676568
# [30]	train-logloss:0.676334
# [31]	train-logloss:0.676125
# [32]	train-logloss:0.675963
# [33]	train-logloss:0.675783
# [34]	train-logloss:0.675627
# [35]	train-logloss:0.675445
# [36]	train-logloss:0.675239
# [37]	train-logloss:0.675137
# [38]	train-logloss:0.674933
# [39]	train-logloss:0.674655
# [40]	train-logloss:0.674505
# [41]	train-logloss:0.674267
# [42]	train-logloss:0.674125
# [43]	train-logloss:0.673993
# [44]	train-logloss:0.673849
# [45]	train-logloss:0.673653
# [46]	train-logloss:0.673468
# [47]	train-logloss:0.673383
# [48]	train-logloss:0.673244
# [49]	train-logloss:0.673091
# [50]	train-logloss:0.672977
# [51]	train-logloss:0.67286
# [52]	train-logloss:0.6727
# [53]	train-logloss:0.672601
# [54]	train-logloss:0.672529
# [55]	train-logloss:0.672339
# [56]	train-logloss:0.672204
# [57]	train-logloss:0.672094
# [58]	train-logloss:0.671982
# [59]	train-logloss:0.671856
# [60]	train-logloss:0.671715
# [61]	train-logloss:0.671632
# [62]	train-logloss:0.671557
# [63]	train-logloss:0.671433
# [64]	train-logloss:0.671282
# [65]	train-logloss:0.671229
# [66]	train-logloss:0.671103
# [67]	train-logloss:0.671032
# [68]	train-logloss:0.670915
# [69]	train-logloss:0.670838
# [70]	train-logloss:0.670741
# [71]	train-logloss:0.670567
# [72]	train-logloss:0.670503
# [73]	train-logloss:0.670359
# [74]	train-logloss:0.670302
# [75]	train-logloss:0.670212
# [76]	train-logloss:0.670102
# [77]	train-logloss:0.670009
# [78]	train-logloss:0.669953
# [79]	train-logloss:0.669915
# [80]	train-logloss:0.66984
# [81]	train-logloss:0.669714
# [82]	train-logloss:0.669665
# [83]	train-logloss:0.669559
# [84]	train-logloss:0.669433
# [85]	train-logloss:0.669391
# [86]	train-logloss:0.669349
# [87]	train-logloss:0.669242
# [88]	train-logloss:0.66917
# [89]	train-logloss:0.669113
# [90]	train-logloss:0.669054
# [91]	train-logloss:0.669016
# [92]	train-logloss:0.668977
# [93]	train-logloss:0.668902
# [94]	train-logloss:0.668823
# [95]	train-logloss:0.668765
# [96]	train-logloss:0.668711
# [97]	train-logloss:0.668695
# [98]	train-logloss:0.668616
# [99]	train-logloss:0.668579
# [100]	train-logloss:0.668515
# [101]	train-logloss:0.668493
# [102]	train-logloss:0.668438
# [103]	train-logloss:0.668383
# [104]	train-logloss:0.668323
# [105]	train-logloss:0.668278
# [106]	train-logloss:0.668217
# [107]	train-logloss:0.66818
# [108]	train-logloss:0.668142
# [109]	train-logloss:0.668075
# [110]	train-logloss:0.667994
# [111]	train-logloss:0.667941
# [112]	train-logloss:0.667897
# [113]	train-logloss:0.667864
# [114]	train-logloss:0.667825
# [115]	train-logloss:0.667801
# [116]	train-logloss:0.667726
# [117]	train-logloss:0.667641
# [118]	train-logloss:0.667604
# [119]	train-logloss:0.667577
# [120]	train-logloss:0.667542
# [121]	train-logloss:0.667517
# [122]	train-logloss:0.667447
# [123]	train-logloss:0.667399
# [124]	train-logloss:0.667362
# [125]	train-logloss:0.66733
# [126]	train-logloss:0.66724
# [127]	train-logloss:0.667204
# [128]	train-logloss:0.667186
# [129]	train-logloss:0.667118
# [130]	train-logloss:0.667072
# [131]	train-logloss:0.667023
# [132]	train-logloss:0.666982
# [133]	train-logloss:0.66694
# [134]	train-logloss:0.666923
# [135]	train-logloss:0.666864
# [136]	train-logloss:0.666806
# [137]	train-logloss:0.666784
# [138]	train-logloss:0.666761
# [139]	train-logloss:0.666717
# [140]	train-logloss:0.666676
# [141]	train-logloss:0.666628
# [142]	train-logloss:0.666576
# [143]	train-logloss:0.666547
# [144]	train-logloss:0.666472
# [145]	train-logloss:0.666404
# [146]	train-logloss:0.666398
# [147]	train-logloss:0.666323
# [148]	train-logloss:0.666302
# [149]	train-logloss:0.666272
# [150]	train-logloss:0.666247
# [151]	train-logloss:0.666241
# [152]	train-logloss:0.66621
# [153]	train-logloss:0.666168
# [154]	train-logloss:0.666133
# [155]	train-logloss:0.666127
# [156]	train-logloss:0.666106
# [157]	train-logloss:0.666059
# [158]	train-logloss:0.666019
# [159]	train-logloss:0.665974
# [160]	train-logloss:0.665943
# [161]	train-logloss:0.665939
# [162]	train-logloss:0.665862
# [163]	train-logloss:0.665833
# [164]	train-logloss:0.66579
# [165]	train-logloss:0.665778
# [166]	train-logloss:0.665747
# [167]	train-logloss:0.6657
# [168]	train-logloss:0.665628
# [169]	train-logloss:0.665592
# [170]	train-logloss:0.665549
# [171]	train-logloss:0.665502
# [172]	train-logloss:0.665467
# [173]	train-logloss:0.665429
# [174]	train-logloss:0.665416
# [175]	train-logloss:0.665369
# [176]	train-logloss:0.665349
# [177]	train-logloss:0.665308
# [178]	train-logloss:0.665271
# [179]	train-logloss:0.665208
# [180]	train-logloss:0.665193
# [181]	train-logloss:0.665159
# [182]	train-logloss:0.665146
# [183]	train-logloss:0.665115
# [184]	train-logloss:0.665078
# [185]	train-logloss:0.665054
# [186]	train-logloss:0.665038
# [187]	train-logloss:0.664982
# [188]	train-logloss:0.664934
# [189]	train-logloss:0.664909
# [190]	train-logloss:0.6649
# [191]	train-logloss:0.664855
# [192]	train-logloss:0.664831
# [193]	train-logloss:0.664816
# [194]	train-logloss:0.664757
# [195]	train-logloss:0.664738
# [196]	train-logloss:0.664729
# [197]	train-logloss:0.664694
# [198]	train-logloss:0.664656
# [199]	train-logloss:0.664618

# %%
predicted_xgb = gbm.predict(xgb.DMatrix(test[x_train.columns]))

# %%
# Create solution dataframe
solution_xgb = pd.DataFrame(test_data['ID'])
solution_xgb = pd.concat([solution_xgb, pd.DataFrame(predicted_xgb, columns=['Outcome'])], axis=1)
solution_xgb
# Out:
#               ID   Outcome
# 0          1_554  0.524737
# 1          2_554  0.399330
# 2          3_554  0.472769
# 3          4_554  0.207324
# 4          6_554  0.446963
# 5          7_554  0.486172
# 6          9_554  0.460272
# 7         10_554  0.576876
# 8         11_554  0.471126
# 9         12_554  0.650570
# 10        13_554  0.456612
# 11        14_554  0.501429
# 12        15_554  0.445622
# 13        16_554  0.498612
# 14        17_554  0.576512
# 15        18_554  0.500916
# 16        19_554  0.310717
# 17        20_554  0.547986
# 18        21_554  0.412725
# 19        22_554  0.494171
# 20        23_554  0.496467
# 21        24_554  0.505808
# 22        25_554  0.534932
# 23        26_554  0.467502
# 24        27_554  0.547232
# 25        28_554  0.640078
# 26        29_554  0.483457
# 27        30_554  0.535349
# 28        31_554  0.292998
# 29        32_554  0.541293
# ...          ...       ...
# 101916  2169_953  0.446654
# 101917  2170_953  0.473034
# 101918  2171_953  0.414362
# 101919  2172_953  0.419208
# 101920  2173_953  0.428403
# 101921  2174_953  0.456901
# 101922  2175_953  0.426478
# 101923  2176_953  0.361693
# 101924  2177_953  0.361433
# 101925  2178_953  0.499166
# 101926  2179_953  0.492669
# 101927  2180_953  0.407284
# 101928  2181_953  0.426029
# 101929  2182_953  0.398556
# 101930  2183_953  0.494010
# 101931  2185_953  0.560578
# 101932  2186_953  0.409716
# 101933  2187_953  0.385533
# 101934  2188_953  0.377297
# 101935  2189_953  0.364499
# 101936  2190_953  0.263549
# 101937  2191_953  0.550216
# 101938  2192_953  0.464502
# 101939  2193_953  0.570284
# 101940  2194_953  0.397968
# 101941  2195_953  0.394927
# 101942  2196_953  0.458162
# 101943  2197_953  0.488191
# 101944  2198_953  0.395509
# 101945  2199_953  0.446825
#
# [101946 rows x 2 columns]

# %%
# Export solution to csv file
solution_xgb.to_csv('../submissions/solution_xgb.csv', index=False)
